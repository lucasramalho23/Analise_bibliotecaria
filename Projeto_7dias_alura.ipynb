# %%
import pandas as pd
import numpy as np

# %%
# importando os dados

dados_2010_1 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20101.csv')
dados_2010_2 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20102.csv')
dados_2011_1 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20111.csv')
dados_2011_2 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20112.csv')
dados_2012_1 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20121.csv')
dados_2012_2 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20122.csv')
dados_2013_1 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20131.csv')
dados_2013_2 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20132.csv')
dados_2014_1 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20141.csv')
dados_2014_2 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20142.csv')
dados_2015_1 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20151.csv')
dados_2015_2 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20152.csv')
dados_2016_1 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20161.csv')
dados_2016_2 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20162.csv')
dados_2017_1 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20171.csv')
dados_2017_2 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20172.csv')
dados_2018_1 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20181.csv')
dados_2018_2 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20182.csv')
dados_2019_1 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20191.csv')
dados_2019_2 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20192.csv')
dados_2020_1 = pd.read_csv(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_emprestimos\emprestimos-20101.csv')

# %%
emprestimos_biblioteca = pd.concat([dados_2010_1,dados_2010_2,dados_2011_1,dados_2011_2,dados_2012_1,dados_2012_2,dados_2013_1,dados_2013_2,dados_2014_1,
                                    dados_2014_2,dados_2015_1,dados_2015_2,dados_2016_1,dados_2016_2,dados_2017_1,dados_2017_2,dados_2018_1,dados_2018_2,
                                    dados_2019_1,dados_2019_2,dados_2020_1],ignore_index=True)
emprestimos_biblioteca
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2326809         919377       C019571                            NaN
# 2326810         919379       C019573                            NaN
# 2326811         919381       C020714                            NaN
# 2326812         919382       C020845                            NaN
# 2326813         919431       Y011015                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
emprestimos_biblioteca=emprestimos_biblioteca.dropna()

# %%
emprestimos_biblioteca.isna().sum()
# Out:
# id_emprestimo           0
# codigo_barras           0
# data_renovacao          0
# data_emprestimo         0
# data_devolucao          0
# matricula_ou_siape      0
# tipo_vinculo_usuario    0
# dtype: int64

# %%
emprestimos_biblioteca=emprestimos_biblioteca.drop_duplicates()

# %%
dados_exemplares = pd.read_parquet(r'c:\Users\55819\Downloads\7_Days_of_Code_Alura-Python-Pandas-main\7_Days_of_Code_Alura-Python-Pandas-main\Dia_1-Importando_dados\Datasets\dados_exemplares.parquet')
dados_exemplares
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %%
dados_completos = emprestimos_biblioteca.merge(dados_exemplares)
dados_completos.head(1)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709686    2006017618  2010/01/26 08:07:01.738000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO       195347  Acervo Circulante
#
#                                           biblioteca status_material  \
# 0  Biblioteca Setorial Prof. Rodolfo Helinski - E...         REGULAR
#
#    localizacao  registro_sistema
# 0          640             75019

# %%
lista_cdu = []
for cdu in dados_completos['localizacao']:
    if(cdu <100):
        lista_cdu.append('Generalidades e Ciência e conhecimento')
    elif(cdu < 200):
        lista_cdu.append('Filosofia e psicologia')
    elif(cdu <300):
        lista_cdu.append('Religião')
    elif(cdu < 400):
        lista_cdu.append('Ciências sociais')
    elif(cdu < 500):
        lista_cdu.append('Classe vaga')
    elif(cdu < 600):
        lista_cdu.append('Matemática e ciências naturais')
    elif(cdu < 700):
        lista_cdu.append('Ciências aplicadas')
    elif(cdu < 800):
        lista_cdu.append('Belas artes')
    elif(cdu < 900):
        lista_cdu.append('Linguagem')
    else:
        lista_cdu.append('Geografia. Biografia. História')
    
dados_completos['cdu'] = lista_cdu

# %%
dados_completos=dados_completos.drop(columns='registro_sistema')

# %%
dados_completos.matricula_ou_siape = dados_completos.matricula_ou_siape.astype(str)

# %%
dados_completos.head(1)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709686    2006017618  2010/01/26 08:07:01.738000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008112114.0  ALUNO DE PÓS-GRADUAÇÃO       195347  Acervo Circulante
#
#                                           biblioteca status_material  \
# 0  Biblioteca Setorial Prof. Rodolfo Helinski - E...         REGULAR
#
#    localizacao                 cdu
# 0          640  Ciências aplicadas

# %% [markdown]
# # visualização de alguns dados

# %% [markdown]
# ### quantidade total de exemplares emprestados por cada ano

# %% [markdown]
# ### verificando emprestimos realizados e exemplares

# %%
# emprestimos realizados ao total

emprestimos = len(dados_completos['id_emprestimo'].drop_duplicates())
emprestimos
# Out:
# 897500

# %%
# exemplares emprestados ao total

exemplares = len(dados_completos['id_emprestimo'])
exemplares
# Out:
# 899024

# %%
emprestimos_data = pd.DataFrame(dados_completos['data_emprestimo'].value_counts().reset_index())
emprestimos_data.columns = ['data','quantidade']
emprestimos_data['data'] = pd.to_datetime(emprestimos_data['data'])
emprestimos_data
# Out:
#                           data  quantidade
# 0      2015-05-05 20:37:19.551           3
# 1      2018-11-22 18:28:01.619           3
# 2      2014-05-12 09:56:18.787           3
# 3      2014-07-14 15:35:51.822           3
# 4      2017-11-06 19:52:32.782           3
# ...                        ...         ...
# 897490 2011-02-22 11:33:43.233           1
# 897491 2011-03-25 15:44:17.214           1
# 897492 2011-05-31 17:42:49.464           1
# 897493 2011-07-11 14:59:24.961           1
# 897494 2019-12-30 17:48:53.039           1
#
# [897495 rows x 2 columns]

# %%
emprestimos_por_ano = dados_completos['data_emprestimo'].groupby(by=emprestimos_data['data'].dt.year).count()
emprestimos_por_ano.index.name = 'ano'
emprestimos_por_ano = pd.DataFrame(emprestimos_por_ano)
emprestimos_por_ano.rename(columns={'data_emprestimo':'quantidade'},inplace=True)
emprestimos_por_ano
# Out:
#         quantidade
# ano
# 2010.0       71277
# 2011.0       93679
# 2012.0      103832
# 2013.0      105290
# 2014.0       94010
# 2015.0       85249
# 2016.0       94696
# 2017.0       93878
# 2018.0       81628
# 2019.0       73956

# %% [markdown]
# ### quantidade de exemplares emprestados por ano

# %%
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt




sns.set_theme(context='notebook', 
              style='darkgrid', 
              palette='deep', 
              font_scale=1.3, 
              rc={"figure.figsize":(15,8)})

ax = sns.lineplot(data=emprestimos_por_ano,x='ano',y='quantidade')
ax.set(xlabel=None,ylabel=None)
ax.tick_params(axis='x', rotation=30)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))   

ax.set_title('Quantidade de exemplares emprestados do SISBI por ano'+'\n',size=20,loc='left',weight='bold')

ax=ax

# %% [markdown]
# Percebe-se que entre o fim de 2012 e após de 2018 os emprestimos diminuiram muito
#
# É importante a direção da biblioteca investigar o que está ocorrendo desde 2013 com os procedimentos realizados.
# Alguns questionamentos importantes que deve-se levar a direção, para que seja aprofundada em outra análise:
#
# * O número de alunos da universidade vem diminuindo?
# * Como está a pesquisa de satisfação dos usuários da biblioteca?
# * O acervo está atualizado?
# * Quais são as estratégias de marketing que a biblioteca está realizando?
# * O que ocorreu de diferente em 2017 em relação a 2016 e 2015 para que o número tenha se elevado?
# * E em 2019?

# %% [markdown]
# ### quantos emprestimos por mês?

# %%
emprestimo_mes = dados_completos['data_emprestimo'].groupby(by=emprestimos_data['data'].dt.month).count()
emprestimo_mes.index.name = 'Mês'
emprestimo_mes = pd.DataFrame(emprestimo_mes)
emprestimo_mes.rename(columns={'data_emprestimo':'quantidade'},inplace=True)
emprestimo_mes
# Out:
#       quantidade
# Mês
# 1.0        34340
# 2.0       105370
# 3.0       106700
# 4.0        91561
# 5.0        81363
# 6.0        44836
# 7.0        64386
# 8.0       110902
# 9.0        92869
# 10.0       81656
# 11.0       56367
# 12.0       27145

# %% [markdown]
# ### Mudando os nomes da coluna meses:

# %%
dicionario_meses = {1:'Jan',2:'Fev',3:'Mar',4:'Abr',
                    5:'Mai',6:'Jun',7:'Jul',8:'Ago',
                    9:'Set',10:'Out',11:'Nov',12:'Dez'}



emprestimo_mes.index = emprestimo_mes.index.map(dicionario_meses)
emprestimo_mes
# Out:
#      quantidade
# Mês
# Jan       34340
# Fev      105370
# Mar      106700
# Abr       91561
# Mai       81363
# Jun       44836
# Jul       64386
# Ago      110902
# Set       92869
# Out       81656
# Nov       56367
# Dez       27145

# %%
ax = sns.lineplot(data=emprestimo_mes,x='Mês',y='quantidade')
ax.set(xlabel='Mêses',ylabel='Quantidade')
ax.tick_params(axis='x', rotation=30)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))   

ax.set_title("Quantidade de exemplares emprestados do SISBI por mês (2010 - 2018)"+"\n",size=20,loc='left',weight='bold')

ax=ax

# %% [markdown]
# * Nota-se que os meses com maior aderência aos emprestimos são MAR e AGO , por serem meses iniciais de semestre e quando professores pedem projetos
#
# * percebe-se também uma dimunuição nos meses JAN , JUN e DEZ , Por serem meses de férias. Contudo os valores não são nulos, isso significa que alguns alunos aderem aos estudos nas férias
#
# * Os mese de JAN e FEV mostram uma diferença absurda, que pode significar que os alunos assim que voltam as sua rotina tem uma rotina bem agitada e precisam colocar os estudos em dia.
#
# * Os meses que precisam de uma atenção a mais são de ABR a OUT, por que é nesse período que ocorre uma baixa muito grande e depois uma alta grande também. isso mostra que a biblioteca deve montar um esquema de MARKETING do tipo promoções ou uma divulgação melhor para não ocorrer essa volatilidade como vem acontecendo

# %% [markdown]
# ## Qual a quantidade de emprestimos por hora ao longo do dia?

# %%
dados_completos.data_emprestimo
# Out:
# 0         2010/01/04 08:08:44.081000000
# 1         2010/04/05 11:25:57.627000000
# 2         2012/02/24 16:18:40.959000000
# 3         2012/03/28 14:33:04.249000000
# 4         2012/11/14 12:41:25.081000000
#                       ...
# 899019    2019/12/30 10:24:38.515000000
# 899020    2019/12/30 11:24:56.727000000
# 899021    2019/12/30 13:08:42.910000000
# 899022    2019/12/30 14:23:44.317000000
# 899023    2019/12/30 17:48:53.039000000
# Name: data_emprestimo, Length: 899024, dtype: object

# %%
emprestimos_por_hora = emprestimos_data.groupby(by=emprestimos_data.data.dt.hour).count()
emprestimos_por_hora.index.name = 'horas'
emprestimos_por_hora = emprestimos_por_hora.reset_index()
emprestimos_por_hora

# ficou estranho pra poder o gráfico ler, não entendi o porque tive que fazer assim.
# quem  souber e poder me ajudar
# Out:
#     horas   data  quantidade
# 0       0      2           2
# 1       6      1           1
# 2       7   7573        7573
# 3       8  45083       45083
# 4       9  55258       55258
# 5      10  80161       80161
# 6      11  76918       76918
# 7      12  65767       65767
# 8      13  55141       55141
# 9      14  65460       65460
# 10     15  71197       71197
# 11     16  91866       91866
# 12     17  81267       81267
# 13     18  81227       81227
# 14     19  43742       43742
# 15     20  56937       56937
# 16     21  19820       19820
# 17     22     61          61
# 18     23     14          14

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(data=emprestimos_por_hora, y='data', x='horas',hue='data',palette='Blues',dodge=False)
plt.legend([],[], frameon=False)
plt.xlabel('Horas')
plt.ylabel('Quantidade de Empréstimos')
plt.title('Quantidade de Empréstimos por Hora')
plt.show()

# %% [markdown]
# * No período entre (10:00 e 17:00) são os picos de emprestimos
#
# * Nos períodos de (07:00 as 09:00) e (19:00 as 21:00) podem ser usados para outras atividades além do atendimento

# %% [markdown]
# ### Continuação da analise dos dados

# %%
# verificando valores unicos do vinculo dos usuários

dados_completos.tipo_vinculo_usuario.unique()
# Out:
# array(['ALUNO DE PÓS-GRADUAÇÃO', 'ALUNO DE GRADUAÇÃO', 'DOCENTE EXTERNO',
#        'DOCENTE', 'SERVIDOR TÉCNICO-ADMINISTRATIVO',
#        'ALUNO MÉDIO/TÉCNICO', 'USUÁRIO EXTERNO'], dtype=object)

# %%
dados_completos.colecao.unique()
# Out:
# array(['Acervo Circulante', 'Monografias', 'Publicações de Autores do RN',
#        'Multimeios', 'Eventos', 'Publicações da UFRN', 'Folhetos',
#        'Obras de Referência', 'Dissertações', 'Coleção Zila Mamede',
#        'Coleção Mossoroense', 'Trabalho Acadêmico',
#        'Necessidades Educacionais Específicas', 'Obras Raras',
#        'Literatura de Cordel', 'Teses'], dtype=object)

# %%
dados_completos.biblioteca.unique()
# Out:
# array(['Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba',
#        'Biblioteca Central Zila Mamede',
#        'Biblioteca Setorial Bertha Cruz Enders - \xadEscola de Saúde da UFRN - ESUFRN',
#        'Biblioteca Setorial do Centro Ciências da Saúde - CCS',
#        'Biblioteca Setorial Prof. Alberto Moreira Campos - \xadDepartamento de Odontologia',
#        'Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA',
#        'Biblioteca Setorial Prof. Horácio Nicolas Solimo - \xad Engenharia Química - EQ - CT',
#        'Biblioteca Setorial Prof. Ronaldo Xavier de Arruda - CCET',
#        'Biblioteca Setorial Prof. Francisco Gurgel De Azevedo - Instituto Química - IQ',
#        'Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA',
#        'Biblioteca Setorial do Departamento de Artes - DEART',
#        'Biblioteca Setorial Prof. Dr. Marcelo Bezerra de Melo Tinôco - DARQ - \xadCT',
# ...

# %%
dados_completos.cdu.unique()
# Out:
# array(['Ciências aplicadas', 'Linguagem', 'Ciências sociais',
#        'Geografia. Biografia. História', 'Matemática e ciências naturais',
#        'Religião', 'Belas artes',
#        'Generalidades e Ciência e conhecimento', 'Filosofia e psicologia'],
#       dtype=object)

# %%
# função para verificar frequência
dados_completos['data_emprestimo'] = pd.to_datetime(dados_completos['data_emprestimo'])
def frequencia(variavel):
    dataframe = pd.DataFrame(dados_completos[variavel].value_counts())
    dataframe.columns = ['quantidade']
    dataframe['percentual'] = round((dataframe.quantidade / dataframe.quantidade.sum())*100,1)
    return dataframe

# %%
frequencia('tipo_vinculo_usuario')
# Out:
#                                  quantidade  percentual
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                   719240        80.0
# ALUNO DE PÓS-GRADUAÇÃO               129525        14.4
# DOCENTE                               26132         2.9
# SERVIDOR TÉCNICO-ADMINISTRATIVO       13333         1.5
# ALUNO MÉDIO/TÉCNICO                    8072         0.9
# DOCENTE EXTERNO                        2716         0.3
# USUÁRIO EXTERNO                           6         0.0

# %% [markdown]
# * percebe-se que os alunos que estão na sua primeira graduação são mais interessados em leitura bibliotecária.
#
# * mesmo os alunos pós-graduandos só terem 15%  do percentual dos emprestimos, isso mostra que eles devem provavelmente ter enfoque maior nos artigos cientificos.
#
# * essa margem de porcentagem é uma métrica geral baseada nos emprestimos

# %%
frequencia('colecao')
# Out:
#                                        quantidade  percentual
# colecao
# Acervo Circulante                          897621        99.8
# Monografias                                   560         0.1
# Publicações de Autores do RN                  328         0.0
# Publicações da UFRN                           223         0.0
# Multimeios                                     71         0.0
# Obras de Referência                            60         0.0
# Dissertações                                   50         0.0
# Folhetos                                       35         0.0
# Coleção Mossoroense                            19         0.0
# Eventos                                        16         0.0
# Coleção Zila Mamede                            14         0.0
# Necessidades Educacionais Específicas          14         0.0
# Literatura de Cordel                            6         0.0
# Teses                                           3         0.0
# ...

# %%
frequencia('biblioteca')
# Out:
#                                                     quantidade  percentual
# biblioteca
# Biblioteca Central Zila Mamede                          676572        75.3
# Biblioteca Setorial do Centro Ciências da Saúde...       57997         6.5
# Biblioteca Setorial Prof. Alberto Moreira Campo...       25349         2.8
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       23005         2.6
# Biblioteca Setorial da Faculdade de Ciências da...       21713         2.4
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       16425         1.8
# Biblioteca Setorial do Centro de Ciências Human...       14125         1.6
# Biblioteca Setorial Prof. Francisco Gurgel De A...       11289         1.3
# Biblioteca Setorial Prof. Ronaldo Xavier de Arr...        8775         1.0
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...        8280         0.9
# Biblioteca Setorial Profª. Maria José Mamede Ga...        8125         0.9
# ...

# %% [markdown]
# * pelo tamanho da Biblioteca Central Zila Mamede ser bem maior que as outras era de se esperar que fosse a mais utilizada
#
# * verificando o ranking, torna-se visivel que existe uma predominância das bibliotecas sobre ciências

# %%
frequencia('cdu')
# Out:
#                                         quantidade  percentual
# cdu
# Ciências aplicadas                          633689        70.5
# Ciências sociais                            156092        17.4
# Matemática e ciências naturais               26697         3.0
# Generalidades e Ciência e conhecimento       25283         2.8
# Religião                                     24966         2.8
# Filosofia e psicologia                       24190         2.7
# Geografia. Biografia. História                2799         0.3
# Belas artes                                   2668         0.3
# Linguagem                                     2640         0.3

# %% [markdown]
# * como foi dito na análise anterior, os temas que envolvem ciências são mais procurados pelos estudantes
#
# * isso pode ocorrer pelas simples explicações que os artigos bibliotecários tem.
#
# * outro ponto a se entender é o porque que Geografia/Biografia/ História/	Belas artes	/ Linguagem estão com um busca tão pequena comparada aos outros

# %% [markdown]
# ## Graduandos

# %%
# filtrando alunos de graduação
alunos_graduacao = dados_completos.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
alunos_graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        718146
# Monografias                                 518
# Publicações de Autores do RN                221
# Publicações da UFRN                         159
# Obras de Referência                          49
# Multimeios                                   44
# Dissertações                                 30
# Folhetos                                     25
# Eventos                                      14
# Coleção Mossoroense                          12
# Necessidades Educacionais Específicas         9
# Coleção Zila Mamede                           6
# Literatura de Cordel                          4
# Obras Raras                                   2
# Trabalho Acadêmico                            1
# Name: count, dtype: int64

# %%
# criando tabela com acervo circulante

aluno_graduacao_acervo_circulante = alunos_graduacao.query('colecao == "Acervo Circulante"')
# transformar em dataframe
aluno_graduacao_acervo_circulante = pd.DataFrame(aluno_graduacao_acervo_circulante)
#transformar data_emprestimo em datetime para var criada no inicio
aluno_graduacao_acervo_circulante['data_emprestimo'] =pd.to_datetime(aluno_graduacao_acervo_circulante['data_emprestimo'])
#separar por ano
aluno_graduacao_acervo_circulante['Ano'] = aluno_graduacao_acervo_circulante['data_emprestimo'].dt.year
#separar por mes
aluno_graduacao_acervo_circulante['Mês'] = aluno_graduacao_acervo_circulante['data_emprestimo'].dt.month
# localizar na tabela ano e mes [:,['Ano','Mês']]
aluno_graduacao_acervo_circulante = aluno_graduacao_acervo_circulante.loc[:,['Ano','Mês']]
# fazer contagem do frame quantidade e resetar  o index
aluno_graduacao_acervo_circulante = aluno_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
# printando na tela
aluno_graduacao_acervo_circulante
# Out:
#       Ano  Mês  quantidade
# 0    2013    2       11739
# 1    2011    8       11696
# 2    2012    8       11641
# 3    2015    2       11374
# 4    2012    3       10814
# ..    ...  ...         ...
# 115  2017   12        1334
# 116  2019    1        1330
# 117  2010   12        1073
# 118  2019   12         982
# 119  2011    1         519
#
# [120 rows x 3 columns]

# %% [markdown]
# ### plotando

# %%
def gera_box_plot(dataset,x,y,titulo,subtitulo):
  '''
  Esta função irá gerar um gráfico de boxplot.

  Dataset = conjunto de dados do gráfico
  x = valor do eixo x do gráfico
  y = valor do eixo y do gráfico
  título = título do gráfico
  subtitulo = subtitulo do texto
  '''

  sns.set_theme(style="darkgrid", palette='Blues',font_scale=1.3)                    
  plt.figure(figsize=(16,10))                                                           

  ax = sns.boxplot(y= y, x= x, data= dataset,color='#4171EF')                                           
  ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))                


  plt.ylim(0,max(dataset[y])*1.1)                                               #Definir o limite do eixo y
  plt.xlabel('Mês')                                                                     
  plt.ylabel('Quantidade')                                                                    

  ax.set_title(titulo+"\n",size=20,loc='left',weight='bold')
  ax.text(s=subtitulo,x=-0.5,y=max(dataset[y])*1.11,fontsize=18, ha='left',color='gray')

# %%
gera_box_plot(aluno_graduacao_acervo_circulante,'Mês','quantidade','Distribuição dos empréstimos mensais','Realizados pelos alunos de graduação no acervo circulante')

# %% [markdown]
# * Nos meses 1 e 12 (jan e dez), podemos ver que há um declinio muito grande nos emprestimos para a coleção de acervo circulante (deixa isso bem claro).
#
# * Os meses 2 e 8 (fev e ago), existe uma crescente considerável já que é o momento de volta as aulas
#
# * o Gráfico de meses mostra detalhadamente que existe uma baixa bastante perceptível entre o inicio do semestre e o fim

# %%
gera_box_plot(aluno_graduacao_acervo_circulante,'Ano','quantidade','Distribuição dos empréstimos por Ano','Realizados pelos alunos de graduação no acervo circulante')

# %% [markdown]
# * já no gráfico de anos, podemos ter uma percepção um pouco mais constante de 2010 até 2019
#
# * E porque isso acontece? por que o gráfico de anos junta todos os anos e nos mostra altas,médias e baixas.
#
# * Entre 2010 e 2013 existiu uma crescente nos emprestimos da coleção acerco circulante e logo após uma baixa até 2019
#
# * Uma das várias hipóteses que podem existir é que os estudantes passaram a utilizar os seus smartphones e ou notebooks para realizar seus estudos, em vez de ir em bibliotecas realizar emprestimos

# %% [markdown]
# ## Pós-Graduandos

# %%
alunos_pos_graduacao = dados_completos.query('tipo_vinculo_usuario == "ALUNO DE PÓS-GRADUAÇÃO"')
alunos_pos_graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        129317
# Publicações de Autores do RN                 82
# Publicações da UFRN                          49
# Monografias                                  21
# Multimeios                                   15
# Dissertações                                 10
# Folhetos                                      7
# Obras de Referência                           7
# Coleção Mossoroense                           6
# Coleção Zila Mamede                           4
# Necessidades Educacionais Específicas         2
# Literatura de Cordel                          2
# Teses                                         2
# Eventos                                       1
# Name: count, dtype: int64

# %%
# filtrando só os pós-graduandos
aluno_pos_graduacao_acervo_circulante = alunos_pos_graduacao.query('colecao == "Acervo Circulante"')
#transformando em dataframe
aluno_pos_graduacao_acervo_circulante = pd.DataFrame(aluno_pos_graduacao_acervo_circulante)
# transformando em datetime
aluno_pos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(aluno_pos_graduacao_acervo_circulante['data_emprestimo'])
# filtrando por ano 
aluno_pos_graduacao_acervo_circulante['Ano'] = aluno_pos_graduacao_acervo_circulante['data_emprestimo'].dt.year
# filtrando por mes
aluno_pos_graduacao_acervo_circulante['Mês'] = aluno_pos_graduacao_acervo_circulante['data_emprestimo'].dt.month
# localizando melhores resultados
aluno_pos_graduacao_acervo_circulante = aluno_pos_graduacao_acervo_circulante.loc[:,['Ano','Mês']]
# contagem
aluno_pos_graduacao_acervo_circulante = aluno_pos_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
# plotando
aluno_pos_graduacao_acervo_circulante
# Out:
#       Ano  Mês  quantidade
# 0    2017    8        1833
# 1    2016    8        1794
# 2    2015    3        1724
# 3    2018    3        1687
# 4    2014    2        1676
# ..    ...  ...         ...
# 115  2019   12         588
# 116  2011    6         568
# 117  2010    1         556
# 118  2011    1         227
# 119  2010   12         172
#
# [120 rows x 3 columns]

# %%
def gera_box_plot(dataset,x,y,titulo,subtitulo):
  '''
  Esta função irá gerar um gráfico de boxplot.

  Dataset = conjunto de dados do gráfico
  x = valor do eixo x do gráfico
  y = valor do eixo y do gráfico
  título = título do gráfico
  subtitulo = subtitulo do texto
  '''

  sns.set_theme(style="darkgrid", palette='Blues',font_scale=1.3)                    
  plt.figure(figsize=(16,10))                                                           

  ax = sns.boxplot(y= y, x= x, data= dataset,color='#4171EF')                                           
  ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))                


  plt.ylim(0,max(dataset[y])*1.1)                                               #Definir o limite do eixo y
  plt.xlabel('Mês')                                                                     
  plt.ylabel('Quantidade')                                                                    

  ax.set_title(titulo+"\n",size=20,loc='left',weight='bold')
  ax.text(s=subtitulo,x=-0.5,y=max(dataset[y])*1.11,fontsize=18, ha='left',color='gray')

# %%
gera_box_plot(aluno_pos_graduacao_acervo_circulante,'Mês','quantidade','Distribuição dos empréstimos mensais','Realizados pelos alunos de Pós-Graduação no acervo circulante')

# %%
gera_box_plot(aluno_pos_graduacao_acervo_circulante,'Ano','quantidade','Distribuição dos empréstimos Anuais','Realizados pelos alunos de Pós-Graduação no acervo circulante')

# %% [markdown]
# Já os alunos de pós graduação tiveram um aspecto diferente em relação ao declínio a partir de 2013:
#
# * A linha mediana foi diminuindo devagar até 2018. Entretanto valores máximos foram superiores, apenas caindo de fato em 2019.
#
# Nos dois gráficos podemos observar um grande aumento entre 2010 e 2013, o que nos leva a pensar em quais procedimentos estavam sendo realizados neste período para que houvesse esse crescimento.
#
# Nos dois recortes visualizamos que a partir de 2018 tivemos um forte declínio e é um alerta para que a direção possa entender o que está ocorrendo.

# %% [markdown]
# #### Novos dados para novas análises

# %%
cadastro_usuarios_antes_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                        sheet_name='Até 2010',skiprows=1)
cadastro_usuarios_depois_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                        sheet_name='Após 2010',skiprows=1)

# %%
cadastro_usuarios_antes_2010

# %%
# garantindo que terão a mesma coluna para não haver erro ou duplicação de colunas:
cadastro_usuarios_antes_2010.columns = ['matricula_ou_siape','tipo_vinculo_usuario','curso']
cadastro_usuarios_depois_2010.columns= ['matricula_ou_siape','tipo_vinculo_usuario','curso']
cadastro_usuarios_excel = pd.concat([cadastro_usuarios_antes_2010,cadastro_usuarios_depois_2010],ignore_index=True)
#transformando matrícula_ou_siape em string
cadastro_usuarios_excel.matricula_ou_siape = cadastro_usuarios_excel.matricula_ou_siape.astype('string')
# verificando se foi pra string
# cadastro_usuarios_excel.info() - tire do comentário caso deseje
cadastro_usuarios_excel
# Out:
#      matricula_ou_siape tipo_vinculo_usuario                     curso
# 0           190001688.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 1           199014489.0   ALUNO DE GRADUAÇÃO       CIÊNCIAS BIOLÓGICAS
# 2           199735674.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 3           199812431.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 4           199823670.0   ALUNO DE GRADUAÇÃO                  ECOLOGIA
# ...                 ...                  ...                       ...
# 9995      20150116770.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 9996       2015074523.0   ALUNO DE GRADUAÇÃO                     DANÇA
# 9997      20160002745.0   ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 9998      20170086533.0   ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 9999      20180090351.0   ALUNO DE GRADUAÇÃO                     DANÇA
#
# [10000 rows x 3 columns]

# %% [markdown]
# # modificar matricula para string
# #concatenar com a tabela de excel
# # cadastro_completo = pd.concat([cadastro_usuarios_excel,])
# # filtros para alunos para alunos de graduação de 2015 em diante só para matricula e data_emprestimo
# # limpeza dos dados
# # filtrar os cursos selecionados
# # unir os dataframes anteriores com o de cursos selecionados
# # fazer uma tabela de quantidade de emprestimos por curso e por ano
# # por ultimo pivotar a tabela

# %%
# importar arquivo json
cadastro_usuarios_json = pd.read_json('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/cadastro_alunos.json')
cadastro_usuarios_json
# Out:
#      tipo_curso                                          registros
# 0     GRADUACAO  [{"matricula_ou_siape": "2009029003.0", "tipo_...
# 1  POSGRADUACAO  [{"matricula_ou_siape": "2008112114.0", "tipo_...

# %%
cadastro_usuarios_graduacao_json = pd.read_json(cadastro_usuarios_json.registros[0])
cadastro_usuarios_graduacao_json
# Out:
#        matricula_ou_siape tipo_vinculo_usuario                   curso
# 0              2009029003   ALUNO DE GRADUAÇÃO               FILOSOFIA
# 1               200617346   ALUNO DE GRADUAÇÃO                 DIREITO
# 2               200746502   ALUNO DE GRADUAÇÃO  ENGENHARIA DE PETRÓLEO
# 3               200504968   ALUNO DE GRADUAÇÃO           ADMINISTRAÇÃO
# 4               200615572   ALUNO DE GRADUAÇÃO   CIÊNCIA DA COMPUTAÇÃO
# ...                   ...                  ...                     ...
# 62797         20200012706   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62798         20200039601   ALUNO DE GRADUAÇÃO    ENGENHARIA FLORESTAL
# 62799         20200132517   ALUNO DE GRADUAÇÃO               AGRONOMIA
# 62800         20200009344   ALUNO DE GRADUAÇÃO         BIBLIOTECONOMIA
# 62801         20200090284   ALUNO DE GRADUAÇÃO                 DIREITO
#
# [62802 rows x 3 columns]

# %%
# modificar matricula para string
cadastro_usuarios_graduacao_json.matricula_ou_siape = cadastro_usuarios_graduacao_json.matricula_ou_siape.astype('float')
cadastro_usuarios_graduacao_json.matricula_ou_siape = cadastro_usuarios_graduacao_json.matricula_ou_siape.astype('string')

# %%
#concatenar com a tabela de excel

cadastro_completo = pd.concat([cadastro_usuarios_excel,cadastro_usuarios_graduacao_json],ignore_index=True)
cadastro_completo
# Out:
#       matricula_ou_siape tipo_vinculo_usuario                 curso
# 0            190001688.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 1            199014489.0   ALUNO DE GRADUAÇÃO   CIÊNCIAS BIOLÓGICAS
# 2            199735674.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 3            199812431.0   ALUNO DE GRADUAÇÃO                LETRAS
# 4            199823670.0   ALUNO DE GRADUAÇÃO              ECOLOGIA
# ...                  ...                  ...                   ...
# 72797      20200012706.0   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72798      20200039601.0   ALUNO DE GRADUAÇÃO  ENGENHARIA FLORESTAL
# 72799      20200132517.0   ALUNO DE GRADUAÇÃO             AGRONOMIA
# 72800      20200009344.0   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72801      20200090284.0   ALUNO DE GRADUAÇÃO               DIREITO
#
# [72802 rows x 3 columns]

# %%
# filtros para alunos para alunos de graduação de 2015 em diante só para matricula e data_emprestimo
matricula_data_emprestimo = dados_completos.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
# escolher todas as linhas de 2 colunas específicas
matricula_data_emprestimo = matricula_data_emprestimo.loc[:,['matricula_ou_siape','data_emprestimo']]
# filtrar para depois de 2015
matricula_data_emprestimo.data_emprestimo = pd.to_datetime(matricula_data_emprestimo.data_emprestimo)
matricula_data_emprestimo.data_emprestimo = matricula_data_emprestimo.data_emprestimo.dt.year
matricula_data_emprestimo = matricula_data_emprestimo.query('data_emprestimo > 2015')
matricula_data_emprestimo
# Out:
#        matricula_ou_siape  data_emprestimo
# 14          20200002639.0             2019
# 54          20180097370.0             2019
# 79           2014092886.0             2016
# 80           2014092886.0             2017
# 100         20170088770.0             2018
# ...                   ...              ...
# 899010       2012958973.0             2019
# 899011      20190014747.0             2019
# 899021      20190119248.0             2019
# 899022      20190077273.0             2019
# 899023      20190064874.0             2019
#
# [267017 rows x 2 columns]

# %%
# filtrar os cursos selecionados
cadastro_usuarios_cursos_selecionados = cadastro_completo.query("curso == ['BIBLIOTECONOMIA','CIÊNCIAS SOCIAIS','COMUNICAÇÃO SOCIAL','DIREITO','FILOSOFIA','PEDAGOGIA']")
cadastro_usuarios_cursos_selecionados
# Out:
#       matricula_ou_siape tipo_vinculo_usuario             curso
# 8            200031011.0   ALUNO DE GRADUAÇÃO           DIREITO
# 9            200045080.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 15           200115053.0   ALUNO DE GRADUAÇÃO  CIÊNCIAS SOCIAIS
# 18           200123382.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 19           200123730.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# ...                  ...                  ...               ...
# 72789      20200097481.0   ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 72796      20200107087.0   ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 72797      20200012706.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 72800      20200009344.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 72801      20200090284.0   ALUNO DE GRADUAÇÃO           DIREITO
#
# [18833 rows x 3 columns]

# %%
# unir os dataframes anteriores com o de cursos selecionados

cadastro_e_cursos = matricula_data_emprestimo.merge(cadastro_usuarios_cursos_selecionados)
cadastro_e_cursos
# Out:
#       matricula_ou_siape  data_emprestimo tipo_vinculo_usuario  \
# 0          20170088770.0             2018   ALUNO DE GRADUAÇÃO
# 1          20170088770.0             2018   ALUNO DE GRADUAÇÃO
# 2          20170088770.0             2019   ALUNO DE GRADUAÇÃO
# 3          20170088770.0             2018   ALUNO DE GRADUAÇÃO
# 4          20170088770.0             2018   ALUNO DE GRADUAÇÃO
# ...                  ...              ...                  ...
# 72058      20190114260.0             2019   ALUNO DE GRADUAÇÃO
# 72059      20190022598.0             2019   ALUNO DE GRADUAÇÃO
# 72060      20190025571.0             2019   ALUNO DE GRADUAÇÃO
# 72061      20190025571.0             2019   ALUNO DE GRADUAÇÃO
# 72062      20180030970.0             2019   ALUNO DE GRADUAÇÃO
#
#                     curso
# 0               FILOSOFIA
# 1               FILOSOFIA
# 2               FILOSOFIA
# 3               FILOSOFIA
# 4               FILOSOFIA
# ...                   ...
# ...

# %%
cadastro_e_cursos.isna().sum()
# Out:
# matricula_ou_siape      0
# data_emprestimo         0
# tipo_vinculo_usuario    0
# curso                   0
# dtype: int64

# %%
# fazer uma tabela de quantidade de emprestimos por curso e por ano
emprestimos_cursos_selecionados = cadastro_e_cursos.iloc[:,[1,3]].value_counts().reset_index()
emprestimos_cursos_selecionados.columns = ['ANO','CURSO','QUANTIDADE_EMPRESTIMOS']
emprestimos_cursos_selecionados
# Out:
#      ANO               CURSO  QUANTIDADE_EMPRESTIMOS
# 0   2017  COMUNICAÇÃO SOCIAL                    3632
# 1   2016  COMUNICAÇÃO SOCIAL                    3494
# 2   2016           FILOSOFIA                    3432
# 3   2017             DIREITO                    3368
# 4   2017           FILOSOFIA                    3359
# 5   2016             DIREITO                    3344
# 6   2016     BIBLIOTECONOMIA                    3330
# 7   2017     BIBLIOTECONOMIA                    3316
# 8   2017           PEDAGOGIA                    3277
# 9   2016           PEDAGOGIA                    3173
# 10  2017    CIÊNCIAS SOCIAIS                    3124
# 11  2016    CIÊNCIAS SOCIAIS                    3079
# 12  2018  COMUNICAÇÃO SOCIAL                    2944
# 13  2018             DIREITO                    2901
# 14  2018           FILOSOFIA                    2800
# 15  2018     BIBLIOTECONOMIA                    2770
# 16  2018    CIÊNCIAS SOCIAIS                    2770
# ...

# %%
emprestimos_tipo_usuario_curso_pivot = emprestimos_cursos_selecionados.pivot_table(
        index = 'CURSO',
        columns = 'ANO',
        values = 'QUANTIDADE_EMPRESTIMOS',
        fill_value = '-',
        aggfunc= sum,
        margins = True,
        margins_name = 'TOTAL',
)
emprestimos_tipo_usuario_curso_pivot
# Out:
# ANO                  2016   2017   2018   2019  TOTAL
# CURSO
# BIBLIOTECONOMIA      3330   3316   2770   2523  11939
# CIÊNCIAS SOCIAIS     3079   3124   2770   2611  11584
# COMUNICAÇÃO SOCIAL   3494   3632   2944   2627  12697
# DIREITO              3344   3368   2901   2521  12134
# FILOSOFIA            3432   3359   2800   2487  12078
# PEDAGOGIA            3173   3277   2723   2458  11631
# TOTAL               19852  20076  16908  15227  72063

# %% [markdown]
# ### mesmas análises para pós-graduados

# %%
cadastro_usuarios_antes_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                        sheet_name='Até 2010',skiprows=1)
cadastro_usuarios_depois_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                        sheet_name='Após 2010',skiprows=1)

cadastro_usuarios_antes_2010.columns = ['matricula_ou_siape','tipo_vinculo_usuario','curso']
cadastro_usuarios_depois_2010.columns= ['matricula_ou_siape','tipo_vinculo_usuario','curso']
cadastro_usuarios_excel = pd.concat([cadastro_usuarios_antes_2010,cadastro_usuarios_depois_2010],ignore_index=True)
cadastro_usuarios_excel.matricula_ou_siape = cadastro_usuarios_excel.matricula_ou_siape.astype('string')
cadastro_usuarios_excel
# Out:
#      matricula_ou_siape tipo_vinculo_usuario                     curso
# 0           190001688.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 1           199014489.0   ALUNO DE GRADUAÇÃO       CIÊNCIAS BIOLÓGICAS
# 2           199735674.0   ALUNO DE GRADUAÇÃO                MATEMÁTICA
# 3           199812431.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 4           199823670.0   ALUNO DE GRADUAÇÃO                  ECOLOGIA
# ...                 ...                  ...                       ...
# 9995      20150116770.0   ALUNO DE GRADUAÇÃO                    LETRAS
# 9996       2015074523.0   ALUNO DE GRADUAÇÃO                     DANÇA
# 9997      20160002745.0   ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 9998      20170086533.0   ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 9999      20180090351.0   ALUNO DE GRADUAÇÃO                     DANÇA
#
# [10000 rows x 3 columns]

# %%
cadastro_usuarios_posgraduacao_json = pd.read_json(cadastro_usuarios_json.registros[1])

# %%
# modificar matricula para string
cadastro_usuarios_posgraduacao_json.matricula_ou_siape = cadastro_usuarios_posgraduacao_json.matricula_ou_siape.astype('float')
cadastro_usuarios_posgraduacao_json.matricula_ou_siape = cadastro_usuarios_posgraduacao_json.matricula_ou_siape.astype('string')

# %%
cadastro_completo2 = pd.concat([cadastro_usuarios_posgraduacao_json,cadastro_usuarios_excel],ignore_index=True)
cadastro_completo2
# Out:
#       matricula_ou_siape    tipo_vinculo_usuario                     curso
# 0           2008112114.0  ALUNO DE PÓS-GRADUAÇÃO    CIÊNCIAS ODONTOLÓGICAS
# 1           2008106583.0  ALUNO DE PÓS-GRADUAÇÃO    ENGENHARIA DE SOFTWARE
# 2           2011101417.0  ALUNO DE PÓS-GRADUAÇÃO   ARQUITETURA E URBANISMO
# 3           2011113122.0  ALUNO DE PÓS-GRADUAÇÃO                 FILOSOFIA
# 4           2010110903.0  ALUNO DE PÓS-GRADUAÇÃO             ARTES CÊNICAS
# ...                  ...                     ...                       ...
# 29435      20150116770.0      ALUNO DE GRADUAÇÃO                    LETRAS
# 29436       2015074523.0      ALUNO DE GRADUAÇÃO                     DANÇA
# 29437      20160002745.0      ALUNO DE GRADUAÇÃO  ENGENHARIA DA COMPUTAÇÃO
# 29438      20170086533.0      ALUNO DE GRADUAÇÃO           BIBLIOTECONOMIA
# 29439      20180090351.0      ALUNO DE GRADUAÇÃO                     DANÇA
#
# [29440 rows x 3 columns]

# %%
cadastro_usuarios_cursos_pos_graduacao = cadastro_usuarios_posgraduacao_json.query("tipo_vinculo_usuario == 'ALUNO DE PÓS-GRADUAÇÃO'")
cadastro_usuarios_cursos_pos_graduacao
# Out:
#       matricula_ou_siape    tipo_vinculo_usuario  \
# 0           2008112114.0  ALUNO DE PÓS-GRADUAÇÃO
# 1           2008106583.0  ALUNO DE PÓS-GRADUAÇÃO
# 2           2011101417.0  ALUNO DE PÓS-GRADUAÇÃO
# 3           2011113122.0  ALUNO DE PÓS-GRADUAÇÃO
# 4           2010110903.0  ALUNO DE PÓS-GRADUAÇÃO
# ...                  ...                     ...
# 19435      20201013501.0  ALUNO DE PÓS-GRADUAÇÃO
# 19436      20201014062.0  ALUNO DE PÓS-GRADUAÇÃO
# 19437      20201017690.0  ALUNO DE PÓS-GRADUAÇÃO
# 19438      20201014465.0  ALUNO DE PÓS-GRADUAÇÃO
# 19439      20201014993.0  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                      CIÊNCIAS ODONTOLÓGICAS
# 1                      ENGENHARIA DE SOFTWARE
# 2                     ARQUITETURA E URBANISMO
# 3                                   FILOSOFIA
# 4                               ARTES CÊNICAS
# ...                                       ...
# ...

# %%
# escolher todas as linhas de 2 colunas específicas
matricula_data_emprestimo_pos_graduacao = dados_completos.loc[:,['matricula_ou_siape','data_emprestimo']]
# filtrar para depois de 2015
matricula_data_emprestimo_pos_graduacao.data_emprestimo = pd.to_datetime(matricula_data_emprestimo_pos_graduacao.data_emprestimo)
matricula_data_emprestimo_pos_graduacao.data_emprestimo = matricula_data_emprestimo_pos_graduacao.data_emprestimo.dt.year
matricula_data_emprestimo_pos_graduacao = matricula_data_emprestimo_pos_graduacao.query('data_emprestimo >= 2017')
matricula_data_emprestimo_pos_graduacao
# Out:
#        matricula_ou_siape  data_emprestimo
# 14          20200002639.0             2019
# 15                13142.0             2019
# 54          20180097370.0             2019
# 80           2014092886.0             2017
# 100         20170088770.0             2018
# ...                   ...              ...
# 899019          1728614.0             2019
# 899020      20181011423.0             2019
# 899021      20190119248.0             2019
# 899022      20190077273.0             2019
# 899023      20190064874.0             2019
#
# [250082 rows x 2 columns]

# %% [markdown]
# ## Unindo DataFrames de cadastro de usuários e de empréstimos

# %%
emprestimos_pos_graduacao_desde_2017 = matricula_data_emprestimo_pos_graduacao.merge(cadastro_usuarios_cursos_pos_graduacao)
emprestimos_pos_graduacao_desde_2017
# Out:
#       matricula_ou_siape  data_emprestimo    tipo_vinculo_usuario  \
# 0          20171020142.0             2018  ALUNO DE PÓS-GRADUAÇÃO
# 1          20171020142.0             2017  ALUNO DE PÓS-GRADUAÇÃO
# 2          20171020142.0             2018  ALUNO DE PÓS-GRADUAÇÃO
# 3          20171020142.0             2018  ALUNO DE PÓS-GRADUAÇÃO
# 4          20171020142.0             2017  ALUNO DE PÓS-GRADUAÇÃO
# ...                  ...              ...                     ...
# 40276      20191021693.0             2019  ALUNO DE PÓS-GRADUAÇÃO
# 40277      20184001574.0             2019  ALUNO DE PÓS-GRADUAÇÃO
# 40278      20184001574.0             2019  ALUNO DE PÓS-GRADUAÇÃO
# 40279      20194000276.0             2019  ALUNO DE PÓS-GRADUAÇÃO
# 40280      20194000276.0             2019  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                                  BIOQUÍMICA
# 1                                  BIOQUÍMICA
# ...

# %%
# fazer uma tabela de quantidade de emprestimos por curso e por ano
emprestimos_pos_graduacao_desde_2017 = emprestimos_pos_graduacao_desde_2017.iloc[:,[1,3]].value_counts().reset_index()
emprestimos_pos_graduacao_desde_2017.columns = ['ANO','CURSO','QUANTIDADE_EMPRESTIMOS']
emprestimos_pos_graduacao_desde_2017
# Out:
#      ANO                                   CURSO  QUANTIDADE_EMPRESTIMOS
# 0   2017                       CIÊNCIAS DA SAÚDE                    1182
# 1   2017          CIÊNCIA, TECNOLOGIA E INOVAÇÃO                    1149
# 2   2018                  CIÊNCIAS ODONTOLÓGICAS                    1146
# 3   2017       CIÊNCIA E ENGENHARIA DE MATERIAIS                    1127
# 4   2017                  CIÊNCIAS ODONTOLÓGICAS                    1085
# 5   2017                  ENGENHARIA DE SOFTWARE                    1085
# 6   2017                           ADMINISTRAÇÃO                    1084
# 7   2017  GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO                    1084
# 8   2017                              BIOQUÍMICA                    1075
# 9   2019       CIÊNCIA E ENGENHARIA DE MATERIAIS                    1054
# 10  2019                  CIÊNCIAS ODONTOLÓGICAS                    1047
# 11  2017                               FILOSOFIA                    1046
# ...

# %%
emprestimos_pos_graduacao_e_curso_pivot = emprestimos_pos_graduacao_desde_2017.pivot_table(
        index = 'CURSO',
        columns = 'ANO',
        values = 'QUANTIDADE_EMPRESTIMOS'
)
emprestimos_pos_graduacao_e_curso_pivot = emprestimos_pos_graduacao_e_curso_pivot.dropna()

# %%
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                     2017  2018  2019
# CURSO
# ADMINISTRAÇÃO                           1084  1018   723
# ARQUITETURA E URBANISMO                 1005   857   799
# ARTES CÊNICAS                            952   880   811
# BIOINFORMÁTICA                          1042   964   867
# BIOQUÍMICA                              1075   939   874
# CIÊNCIA E ENGENHARIA DE MATERIAIS       1127   956  1054
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          1149   986   899
# CIÊNCIAS DA SAÚDE                       1182   877   848
# CIÊNCIAS ODONTOLÓGICAS                  1085  1146  1047
# DESIGN                                   956   861   854
# ENGENHARIA CIVIL                        1012   908   954
# ENGENHARIA DE SOFTWARE                  1085   942   927
# FILOSOFIA                               1046   947   792
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO  1084   856   811

# %%
previsao_2022 = pd.read_table('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_7-Apresentando_resultados_em_HTML/Dataset/previsao')

# %%
previsao_2022 = previsao_2022['curso previsao_2022'].str.split(' ',expand=True)
previsao_2022
# Out:
#                                          0     1
# 0                            administracao  1905
# 1                  arquitetura_e_urbanismo  1896
# 2                            artes_cenicas  1920
# 3                           bioinformatica  2302
# 4                               bioquimica  2090
# 5        ciencia_e_engenharia_de_materiais  2010
# 6            ciencia_tecnologia_e_inovacao  1960
# 7                        ciencias_da_saude  1730
# 8                   ciencias_odontologicas  2405
# 9                                   design  1900
# 10                        engenharia_civil  1920
# 11                     engenharia_software  1890
# 12                               filosofia  1903
# 13  gestao_da_informacao_e_do_conhecimento  1855

# %%
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                     2017  2018  2019
# CURSO
# ADMINISTRAÇÃO                           1084  1018   723
# ARQUITETURA E URBANISMO                 1005   857   799
# ARTES CÊNICAS                            952   880   811
# BIOINFORMÁTICA                          1042   964   867
# BIOQUÍMICA                              1075   939   874
# CIÊNCIA E ENGENHARIA DE MATERIAIS       1127   956  1054
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          1149   986   899
# CIÊNCIAS DA SAÚDE                       1182   877   848
# CIÊNCIAS ODONTOLÓGICAS                  1085  1146  1047
# DESIGN                                   956   861   854
# ENGENHARIA CIVIL                        1012   908   954
# ENGENHARIA DE SOFTWARE                  1085   942   927
# FILOSOFIA                               1046   947   792
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO  1084   856   811

# %%
previsao_2022.index = emprestimos_pos_graduacao_e_curso_pivot.index
emprestimos_pos_graduacao_e_curso_pivot['2022'] = previsao_2022.iloc[:,1]
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                     2017  2018  2019  2022
# CURSO
# ADMINISTRAÇÃO                           1084  1018   723  1905
# ARQUITETURA E URBANISMO                 1005   857   799  1896
# ARTES CÊNICAS                            952   880   811  1920
# BIOINFORMÁTICA                          1042   964   867  2302
# BIOQUÍMICA                              1075   939   874  2090
# CIÊNCIA E ENGENHARIA DE MATERIAIS       1127   956  1054  2010
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          1149   986   899  1960
# CIÊNCIAS DA SAÚDE                       1182   877   848  1730
# CIÊNCIAS ODONTOLÓGICAS                  1085  1146  1047  2405
# DESIGN                                   956   861   854  1900
# ENGENHARIA CIVIL                        1012   908   954  1920
# ENGENHARIA DE SOFTWARE                  1085   942   927  1890
# FILOSOFIA                               1046   947   792  1903
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO  1084   856   811  1855

# %%
emprestimos_pos_graduacao_e_curso_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, ADMINISTRAÇÃO to GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2017    14 non-null     int64
#  1   2018    14 non-null     int64
#  2   2019    14 non-null     int64
#  3   2022    14 non-null     object
# dtypes: int64(3), object(1)
# memory usage: 560.0+ bytes

# %%
emprestimos_pos_graduacao_e_curso_pivot['2022'] = emprestimos_pos_graduacao_e_curso_pivot['2022'].astype('int')

# %%
emprestimos_pos_graduacao_e_curso_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14 entries, ADMINISTRAÇÃO to GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2017    14 non-null     int64
#  1   2018    14 non-null     int64
#  2   2019    14 non-null     int64
#  3   2022    14 non-null     int32
# dtypes: int32(1), int64(3)
# memory usage: 504.0+ bytes

# %%
def diferenca_percentual_ano_anterior(x,y):
  return round(((x / y * 100) - 100),2)



percentual_2018 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,1],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,0])
percentual_2019 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,2],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,1])
percentual_2022 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,3],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,2])


percentual = pd.DataFrame({'2018':percentual_2018,
                           '2019':percentual_2019,
                           '2022':percentual_2022})
percentual
# Out:
#                                          2018   2019    2022
# CURSO
# ADMINISTRAÇÃO                           -6.09 -28.98  163.49
# ARQUITETURA E URBANISMO                -14.73  -6.77  137.30
# ARTES CÊNICAS                           -7.56  -7.84  136.74
# BIOINFORMÁTICA                          -7.49 -10.06  165.51
# BIOQUÍMICA                             -12.65  -6.92  139.13
# CIÊNCIA E ENGENHARIA DE MATERIAIS      -15.17  10.25   90.70
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO         -14.19  -8.82  118.02
# CIÊNCIAS DA SAÚDE                      -25.80  -3.31  104.01
# CIÊNCIAS ODONTOLÓGICAS                   5.62  -8.64  129.70
# DESIGN                                  -9.94  -0.81  122.48
# ENGENHARIA CIVIL                       -10.28   5.07  101.26
# ENGENHARIA DE SOFTWARE                 -13.18  -1.59  103.88
# FILOSOFIA                               -9.46 -16.37  140.28
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO -21.03  -5.26  128.73

# %%
percentual.reset_index(inplace=True)
percentual.columns = percentual.columns.str.capitalize()
percentual.Curso = percentual.Curso.str.capitalize()

percentual
# Out:
#                                      Curso   2018   2019    2022
# 0                            Administração  -6.09 -28.98  163.49
# 1                  Arquitetura e urbanismo -14.73  -6.77  137.30
# 2                            Artes cênicas  -7.56  -7.84  136.74
# 3                           Bioinformática  -7.49 -10.06  165.51
# 4                               Bioquímica -12.65  -6.92  139.13
# 5        Ciência e engenharia de materiais -15.17  10.25   90.70
# 6           Ciência, tecnologia e inovação -14.19  -8.82  118.02
# 7                        Ciências da saúde -25.80  -3.31  104.01
# 8                   Ciências odontológicas   5.62  -8.64  129.70
# 9                                   Design  -9.94  -0.81  122.48
# 10                        Engenharia civil -10.28   5.07  101.26
# 11                  Engenharia de software -13.18  -1.59  103.88
# 12                               Filosofia  -9.46 -16.37  140.28
# ...

# %% [markdown]
# ### gerando tabela html

# %%
th_props = [
  ('font-size', '1.4rem'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'whitesmoke'),
  ('background-color', '#001692'),
  ('border-radius', '0.25rem'),
  ('box-shadow','0 0 1rem gray')
  ]

td_props = [
  ('font-size', '1rem'),
  ('padding','0.5rem'),
  ('text-align', 'left'),
  ('font-weight', 'bold'),
  ('border-bottom','0.1rem solid lightgray')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

# %%
percentual.style.text_gradient(cmap='RdYlGn',low=1, axis=1,vmax=0.1,vmin=0)\
                              .format('{:.2f} %',subset=['2018','2019','2022'])\
                              .set_table_styles(styles)\
                              .to_html('teste.html',doctype_html =True,
                                       table_attributes='ALIGN=LEFT WIDTH=50% CELLSPACING = 5')
